# %% [markdown]
# # Part 7b: Deployment on PYNQ-Z2
# The following section is the code to execute in the pynq-z2 jupyter notebook to execute NN inference.
#
# The following cells are intended to run on a pynq-z2, they will not run on the server used to train and synthesize models!
#
# First, import our driver `Overlay` class. We'll also load the test data.

# %%
# !pip install pynq
# Out:
# Requirement already satisfied: pynq in /usr/local/share/pynq-venv/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: nest-asyncio in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynq) (1.5.5)
# Requirement already satisfied: pynqmetadata>=0.0.1 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynq) (0.3.1)
# Requirement already satisfied: setuptools>=24.2.0 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynq) (59.6.0)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from pynq) (1.21.5)
# Requirement already satisfied: pynqutils>=0.0.1 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynq) (0.1.0)
# Requirement already satisfied: cffi in /usr/lib/python3/dist-packages (from pynq) (1.15.0)
# Requirement already satisfied: pydantic in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynqmetadata>=0.0.1->pynq) (1.9.1)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynqmetadata>=0.0.1->pynq) (4.9.0)
# Requirement already satisfied: python-magic>=0.4.25 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynqutils>=0.0.1->pynq) (0.4.27)
# Requirement already satisfied: tqdm in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pynqutils>=0.0.1->pynq) (4.64.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/lib/python3/dist-packages (from jsonschema>=3.2.0->pynqmetadata>=0.0.1->pynq) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from jsonschema>=3.2.0->pynqmetadata>=0.0.1->pynq) (0.18.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/share/pynq-venv/lib/python3.10/site-packages (from pydantic->pynqmetadata>=0.0.1->pynq) (4.3.0)

# %%
from axi_stream_driver import NeuralNetworkOverlay
import numpy as np

X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

# %% [markdown]
# Create a `NeuralNetworkOverlay` object. This will download the `Overlay` (bitfile) onto the PL of the pynq-z2. We provide the `X_test.shape` and `y_test.shape` to allocate some buffers for the data transfer.

# %%
nn = NeuralNetworkOverlay('hls4ml_nn.bit', X_test.shape, y_test.shape)

# %% [markdown]
# Now run the prediction! When we set `profile=True` the function times the inference, and prints out a summary as well as returning the profiling information. We also save the output to a file so we can do some validation.

# %%
y_hw, latency, throughput = nn.predict(X_test, profile=True)
# Out:
# Classified 166000 samples in 0.585766 seconds (283389.6129171034 inferences / s)

# %% [markdown]
# An example print out looks like:
#
# ```
# Classified 166000 samples in 0.402568 seconds (412352.6956936468 inferences / s)
# ```
#
# Now let's save the output and transfer this back to the host.

# %%
np.save('y_hw.npy', y_hw)

# %% [markdown]
# Now, go back to the host and follow `part7c_validation.ipynb`
