# %%
import numpy as np
import conifer

# 1. Initialize the accelerator
accelerator = conifer.backends.xilinxhls.runtime.ZynqDriver('conifer_jettag.bit', batch_size=1)

# 2. DEFINE X (This was missing!)
# Create 1 sample with 16 random features to test
X = np.random.rand(1, 16) 

# 3. Format and Run
X = X.astype(np.float32) 
y_pynq = accelerator.decision_function(X)

print("Result:", y_pynq)
# Out:
# Result: [[-0.5439453  1.1416016  1.375     -3.6503906 -3.0107422]]
